# %% [markdown]
# <a href="https://colab.research.google.com/github/arturdiel/unijui-prog-ciencia-de-dados/blob/main/aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "arturdiel"
# !git config --global user.email "arturdanieldiel@gmail.com"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=arturdiel
# user.email=arturdanieldiel@gmail.com
# init.defaultbranch=main

# %%
# !git clone https://github.com/arturdiel/unijui-prog-ciencia-de-dados.git
# Out:
# Cloning into 'unijui-prog-ciencia-de-dados'...
# ...

# %%
# %cd unijui-prog-ciencia-de-dados
# !ls
# !git status
# !git remote -v

# %%
# %%writefile README.md
# # PCD - Aula 03
#
# Arquivos da aula 03: Colab, GitHub e Git
#
# ## Autor
# Artur
# Out:
# Writing README.md

# %%
# !git add .
# !git commit -m "Update class README"
# Out:
# [main (root-commit) 4f46817] Update class README
#  1 file changed, 6 insertions(+)
#  create mode 100644 README.md

# %%
# !git push main
# Out:
# fatal: 'main' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 49C3-9D9F
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as arturdiel
# github.com
#   ✓ Logged in to github.com account arturdiel (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %%
# !git push main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 289 bytes | 289.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/arturdiel/unijui-prog-ciencia-de-dados.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
