# %% [markdown]
# <a href="https://colab.research.google.com/github/arturdiel/unijui-prog-ciencia-de-dados/blob/main/AtividadeAula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input ("Informe um valor de A: "))
b = int (input ("Informe um valor de B: "))
c = int (input ("Informe um valor de C: "))

media = (a+b+c)/3
print(f"A média entre {a}, {b} e {c}, é {media}")
# Out:
# Informe um valor de A: 1
# Informe um valor de B: 1
# Informe um valor de C: 1
# A média de 1, 1 e 1, é 1.0
